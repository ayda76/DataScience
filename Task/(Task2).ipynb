# %%
import pandas as pd
import numpy as np

# %%
#load the datast
stories=pd.read_csv("stories.csv")
stories
# Out:
#                                                    body  \
# 0
# 1
# 2
# 3
# 4     hello and welcome to BBC News a woman who gave...
# ...                                                 ...
# 5176  News. More local help will soon be on the way....
# 5177  with March 1, we start what is called Meteorol...
# 5178  overseas. A massive Russian convoy is headed t...
# 5179  And this morning, the National Hockey League s...
# 5180  thank you very much. Also this morning, the Un...
#
#                                                   topic
# 0              ['39822b5f-e37e-43e8-b997-7142fe55c3ea']
# 1              ['0d817400-3f5d-41e0-929c-c31fdbe75d31']
# 2              ['83a09c6b-5f2f-421f-ae50-b38acca7e008']
# 3              ['6fbf954a-03f9-4782-a65f-783271c9c447']
# 4     ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
# ...                                                 ...
# 5176  ['9ff54ded-904b-4e0c-85ce-a3617f5cb913', '9632...
# 5177           ['9a06646a-e1df-4fca-888e-69658420556b']
# 5178           ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 5179  ['9ff54ded-904b-4e0c-85ce-a3617f5cb913', 'b492...
# 5180  ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
#
# [5181 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords
import nltk
import spacy

# %%
# download the nltk stopwords and spacy english language model
nltk.download('stopwords')
nlp = spacy.load('en_core_web_sm')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#prepare the data and get the vectorizer
def preprocessing_step(text):
  custom_stop_words = ['and', 'the', 'in', 'of', 'to', 'a', 'is', 'that','an','but'] 
  # Combine the NLTK stopwords with the custom stop words
  stop_words = set(stopwords.words('english')).union(set(custom_stop_words))
  vectorizer = CountVectorizer(stop_words=list(stop_words))
  X = vectorizer.fit_transform(text)
  return X,vectorizer

X,vectorizer= preprocessing_step(stories['body'])

# %%
# get the LatentDirichletAllocation model and train it 
from sklearn.decomposition import LatentDirichletAllocation

# number of topics to extract
n_topics = 3 
lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
lda_model.fit(X)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=42)

# %%
pip install --upgrade scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)

# %%
# get the top words for each topic
n_top_words = 5
feature_names = vectorizer.get_feature_names_out()

# function to get the top words for a given topic
def get_top_words(topic):

  return [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
     

# passing the topics to the dataframe
stories['topic_text'] = None

for i, row in stories.iterrows():
    row_text = row['body']
    vectorized_text = vectorizer.transform([row_text])
    topic_dist = lda_model.transform(vectorized_text)[0]
    top_topic = np.argmax(topic_dist)
    top_words = get_top_words(lda_model.components_[top_topic])
    stories.at[i, 'topic_text'] = ', '.join(top_words)


stories
# Out:
#                                                    body  \
# 0
# 1
# 2
# 3
# 4     hello and welcome to BBC News a woman who gave...
# ...                                                 ...
# 5176  News. More local help will soon be on the way....
# 5177  with March 1, we start what is called Meteorol...
# 5178  overseas. A massive Russian convoy is headed t...
# 5179  And this morning, the National Hockey League s...
# 5180  thank you very much. Also this morning, the Un...
#
#                                                   topic  \
# 0              ['39822b5f-e37e-43e8-b997-7142fe55c3ea']
# 1              ['0d817400-3f5d-41e0-929c-c31fdbe75d31']
# 2              ['83a09c6b-5f2f-421f-ae50-b38acca7e008']
# 3              ['6fbf954a-03f9-4782-a65f-783271c9c447']
# 4     ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
# ...                                                 ...
# 5176  ['9ff54ded-904b-4e0c-85ce-a3617f5cb913', '9632...
# 5177           ['9a06646a-e1df-4fca-888e-69658420556b']
# 5178           ['9ff54ded-904b-4e0c-85ce-a3617f5cb913']
# 5179  ['9ff54ded-904b-4e0c-85ce-a3617f5cb913', 'b492...
# 5180  ['83a09c6b-5f2f-421f-ae50-b38acca7e008', '9ff5...
#
#                                  topic_text
# 0     ukraine, president, us, russia, today
# 1     ukraine, president, us, russia, today
# 2     ukraine, president, us, russia, today
# 3     ukraine, president, us, russia, today
# 4              new, police, say, city, year
# ...                                     ...
# 5176  ukraine, president, us, russia, today
# 5177   going, morning, school, today, right
# 5178  ukraine, president, us, russia, today
# 5179  ukraine, president, us, russia, today
# 5180  ukraine, president, us, russia, today
#
# [5181 rows x 3 columns]

# %%
# save the model 
import pickle

pickle.dump(lda_model, open('trained_model.pkl', 'wb'))

# %%
#get the test data from task1
test_data=pd.read_csv("news.csv")
test_data['body']
# Out:
# 0     Well knew. This morning police need your help ...
# 1     a call. San Francisco firefighters rescued a m...
# 2     Paul. Meanwhile, the state set a record in ene...
# 3     Emergency crews in Florida continue to search ...
# 4     But even though the state never ordered rollin...
# 5     aid. And today, president Joe Biden and first ...
# 6     In the last month, there have been numerous da...
# 7     and the warriors are playing the Boston Celtic...
# 8     And San Leandro police searching for the perso...
# 9     The updated Bivalent Coronavirus booster shot ...
# 10    temperatures tonight, only back down to the un...
# 11    And National Guard teams are also on the groun...
# 12    A man died after falling from an escalator aft...
# 13    All right. Well happening today. Friends and f...
# 14    detectives are searching for six people they s...
# 15    San Jose police say a security guard trying to...
# 16    San Jose police just announcing today an arres...
# 17    shooting. Surveillance video shows how a car t...
# Name: body, dtype: object

# %%
#passing the test data to preprocessing_step function
X_test,test_vectorizer= preprocessing_step(test_data['body'])

# %%
# loading the saved model
loaded_model = pickle.load(open('trained_model.pkl', 'rb'))
loaded_model.fit(X_test)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=42)

# %%
### passing topics to dataset

n_top_words = 5
feature_names = test_vectorizer.get_feature_names_out()

test_data['topic_text'] = None

for i, row in test_data.iterrows():
    row_text = row['body']
    vectorized_text = test_vectorizer.transform([row_text])
    topic_dist = loaded_model.transform(vectorized_text)[0]
    top_topic = np.argmax(topic_dist)
    top_words = get_top_words(loaded_model.components_[top_topic])
    test_data.at[i, 'topic_text'] = ', '.join(top_words)


test_data
# Out:
#                                           first_words  \
# 0       Well knew. This morning police need your help
# 1    a call. San Francisco firefighters rescued a man
# 2          Paul. Meanwhile, the state set a record in
# 3   Emergency crews in Florida continue to search for
# 4     But even though the state never ordered rolling
# 5       aid. And today, president Joe Biden and first
# 6         In the last month, there have been numerous
# 7     and the warriors are playing the Boston Celtics
# 8     And San Leandro police searching for the person
# 9   The updated Bivalent Coronavirus booster shot ...
# 10  temperatures tonight, only back down to the un...
# 11           And National Guard teams are also on the
# 12         A man died after falling from an escalator
# 13  All right. Well happening today. Friends and f...
# 14   detectives are searching for six people they say
# 15        San Jose police say a security guard trying
# 16    San Jose police just announcing today an arrest
# 17  shooting. Surveillance video shows how a car t...
#
#                                            last_words  source_video_id  \
# 0   gunpoint, beating him and stealing his cell ph...            18246
# 1               all the way down to the ocean. ocean.            12387
# 2   night through conservation, some 4000 conserva...            16859
# 3             in Florida to more than 850,000 homes.             18246
# 4      feel since their power got cut out needlessly.            16859
# 5    to view the destruction caused by Hurricane Ian.            18246
# 6       are necessary to crack down on those hackers.            18246
# 7             that. We'll see if they get it tonight.            12387
# 8   footage to try to piece together more informat...            16859
# 9   on their vaccinations getting severe illness f...            16859
# 10  stuff. Stay hydrated, take breaks. Don't overd...            16859
# 11  north and South Carolina. Fasttracking federal...            18246
# 12               name or what led to that fall. fall.            18246
# 13  Meanwhile, the suspected killer remains in the...            18246
# 14      with any information is asked to call police.            18246
# 15         not released yet by the Santa Clara County            12387
# 16       not reveal a motive for the deadly shooting.            12387
# 17               this case, please give them a call.             12387
#
#                                                  body    start      end  \
# 0   Well knew. This morning police need your help ...   464928   504300
# 1   a call. San Francisco firefighters rescued a m...   359020        0
# 2   Paul. Meanwhile, the state set a record in ene...    60704   100410
# 3   Emergency crews in Florida continue to search ...   505290   534518
# 4   But even though the state never ordered rollin...   100910   283306
# 5   aid. And today, president Joe Biden and first ...   546494   592450
# 6   In the last month, there have been numerous da...   614910   699230
# 7   and the warriors are playing the Boston Celtic...   419994   649122
# 8   And San Leandro police searching for the perso...   578612   618980
# 9   The updated Bivalent Coronavirus booster shot ...   619310   659730
# 10  temperatures tonight, only back down to the un...  1127008  1207970
# 11  And National Guard teams are also on the groun...   534674   547150
# 12  A man died after falling from an escalator aft...   593490        0
# 13  All right. Well happening today. Friends and f...   218170   345318
# 14  detectives are searching for six people they s...   350830   459134
# 15  San Jose police say a security guard trying to...    98130   275802
# 16  San Jose police just announcing today an arres...   283804   330330
# 17  shooting. Surveillance video shows how a car t...   329682   359678
#
#                               topic_text
# 0   say, power, police, guard, blackouts
# 1          like, two, years, game, games
# 2     russo, last, police, also, custody
# 3          like, two, years, game, games
# 4   say, power, police, guard, blackouts
# 5          like, two, years, game, games
# 6          like, two, years, game, games
# 7          like, two, years, game, games
# 8          like, two, years, game, games
# 9          like, two, years, game, games
# 10         like, two, years, game, games
# 11    russo, last, police, also, custody
# 12         like, two, years, game, games
# 13    russo, last, police, also, custody
# 14  say, power, police, guard, blackouts
# 15  say, power, police, guard, blackouts
# 16    russo, last, police, also, custody
# 17  say, power, police, guard, blackouts

# %%
###converting the topic column to UUID 
import uuid


test_data['uuid_topic'] = None

# Iterating over the rows and producing UUIDs for each topic
for a, row in test_data.iterrows():
    text_topic = row['topic_text']
    generated_uuid = uuid.uuid5(uuid.NAMESPACE_DNS, text_topic)
    test_data.at[a, 'uuid_topic'] = str(generated_uuid)

test_data
# Out:
#                                           first_words  \
# 0       Well knew. This morning police need your help
# 1    a call. San Francisco firefighters rescued a man
# 2          Paul. Meanwhile, the state set a record in
# 3   Emergency crews in Florida continue to search for
# 4     But even though the state never ordered rolling
# 5       aid. And today, president Joe Biden and first
# 6         In the last month, there have been numerous
# 7     and the warriors are playing the Boston Celtics
# 8     And San Leandro police searching for the person
# 9   The updated Bivalent Coronavirus booster shot ...
# 10  temperatures tonight, only back down to the un...
# 11           And National Guard teams are also on the
# 12         A man died after falling from an escalator
# 13  All right. Well happening today. Friends and f...
# 14   detectives are searching for six people they say
# 15        San Jose police say a security guard trying
# 16    San Jose police just announcing today an arrest
# 17  shooting. Surveillance video shows how a car t...
#
#                                            last_words  source_video_id  \
# 0   gunpoint, beating him and stealing his cell ph...            18246
# 1               all the way down to the ocean. ocean.            12387
# 2   night through conservation, some 4000 conserva...            16859
# 3             in Florida to more than 850,000 homes.             18246
# 4      feel since their power got cut out needlessly.            16859
# 5    to view the destruction caused by Hurricane Ian.            18246
# 6       are necessary to crack down on those hackers.            18246
# 7             that. We'll see if they get it tonight.            12387
# 8   footage to try to piece together more informat...            16859
# 9   on their vaccinations getting severe illness f...            16859
# 10  stuff. Stay hydrated, take breaks. Don't overd...            16859
# 11  north and South Carolina. Fasttracking federal...            18246
# 12               name or what led to that fall. fall.            18246
# 13  Meanwhile, the suspected killer remains in the...            18246
# 14      with any information is asked to call police.            18246
# 15         not released yet by the Santa Clara County            12387
# 16       not reveal a motive for the deadly shooting.            12387
# 17               this case, please give them a call.             12387
#
#                                                  body    start      end  \
# 0   Well knew. This morning police need your help ...   464928   504300
# 1   a call. San Francisco firefighters rescued a m...   359020        0
# 2   Paul. Meanwhile, the state set a record in ene...    60704   100410
# 3   Emergency crews in Florida continue to search ...   505290   534518
# 4   But even though the state never ordered rollin...   100910   283306
# 5   aid. And today, president Joe Biden and first ...   546494   592450
# 6   In the last month, there have been numerous da...   614910   699230
# 7   and the warriors are playing the Boston Celtic...   419994   649122
# 8   And San Leandro police searching for the perso...   578612   618980
# 9   The updated Bivalent Coronavirus booster shot ...   619310   659730
# 10  temperatures tonight, only back down to the un...  1127008  1207970
# 11  And National Guard teams are also on the groun...   534674   547150
# 12  A man died after falling from an escalator aft...   593490        0
# 13  All right. Well happening today. Friends and f...   218170   345318
# 14  detectives are searching for six people they s...   350830   459134
# 15  San Jose police say a security guard trying to...    98130   275802
# 16  San Jose police just announcing today an arres...   283804   330330
# 17  shooting. Surveillance video shows how a car t...   329682   359678
#
#                               topic_text                            uuid_topic
# 0   say, power, police, guard, blackouts  5f08968c-e229-598a-aba5-daaf4a2d920a
# 1          like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 2     russo, last, police, also, custody  7c1c33b3-ec59-5aa6-9312-944d96095276
# 3          like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 4   say, power, police, guard, blackouts  5f08968c-e229-598a-aba5-daaf4a2d920a
# 5          like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 6          like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 7          like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 8          like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 9          like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 10         like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 11    russo, last, police, also, custody  7c1c33b3-ec59-5aa6-9312-944d96095276
# 12         like, two, years, game, games  bcbeb58a-3bed-50a9-a5e4-7a342c3c74c3
# 13    russo, last, police, also, custody  7c1c33b3-ec59-5aa6-9312-944d96095276
# 14  say, power, police, guard, blackouts  5f08968c-e229-598a-aba5-daaf4a2d920a
# 15  say, power, police, guard, blackouts  5f08968c-e229-598a-aba5-daaf4a2d920a
# 16    russo, last, police, also, custody  7c1c33b3-ec59-5aa6-9312-944d96095276
# 17  say, power, police, guard, blackouts  5f08968c-e229-598a-aba5-daaf4a2d920a

# %%
#save the results in a new file
test_data.to_csv("finaldataset.csv",index=False)
